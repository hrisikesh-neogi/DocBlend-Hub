# %%
from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader("metaclass.csv")
data = loader.load()

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings


text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(data)

# %%
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI

template = """You are a helpful AI assistant that helps to produce video timestamps along with the topics. 
Instructions:
You need to look into the provided data and summarize the main topics. Then you need to specify the timestamps.
The timestamps given to you is in seconds, you need to convert them into minutes. You should use the format as 
HM:SEC -- where H is the hourly timestamp and the M is the Minute timestamp.

Below are the texts and timestamps for the video.
{video_transcript} """ 

prompt = PromptTemplate(template=template,
                        input_variables=["video_transcript"])
llm = OpenAI()
chain = LLMChain(
    llm=llm, 
    prompt=prompt
)

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.chains import RetrievalQA

embeddings = OpenAIEmbeddings()
db = Chroma.from_documents(docs, embeddings)


qa = RetrievalQA.from_chain_type(llm=OpenAI(), chain_type="stuff", retriever=db.as_retriever())

# %%
docs
# Out:
# [Document(page_content='text: Hello everyone, so welcome to another video of this advanced python series\nstart_time: 0.0\nend_time: 3.72', metadata={'source': 'metaclass.csv', 'row': 0}),
#  Document(page_content='text: So this is the third video of this series. So till so far we have discussed about water meta classes and water decorators.\nstart_time: 4.4\nend_time: 12.91', metadata={'source': 'metaclass.csv', 'row': 1}),
#  Document(page_content='text: And we have seen like there are two types of things we can do to achieve meta programming in Python, right.\nstart_time: 12.91\nend_time: 19.17', metadata={'source': 'metaclass.csv', 'row': 2}),
#  Document(page_content='text: So, one is basically the decoletors and one is metadlases. So, in the previous video if you have seen so,\nstart_time: 19.17\nend_time: 26.56', metadata={'source': 'metaclass.csv', 'row': 3}),
#  Document(page_content='text: I have discussed about the decoytrus in python and in this particular video we are going to discuss\nstart_time: 26.56\nend_time: 31.95', metadata={'source': 'metaclass.csv', 'row': 4}),
#  Document(page_content='text: about what are meta classes and how we can use metaasses. So, basically you will see the structure how Python has used\nstart_time: 31.95\nend_time: 39.53', metadata={'source': 'metaclass.csv', 'row': 5}),
#  Document(page_content='text: Metaclasses and how type has been used. So, these things will be covering in this previous video. So,\nstart_time: 39.53\nend_time: 44.88', metadata={'source': 'metaclass.csv', 'row': 6}),
#  Document(page_content='text: stay tuned and I will see you. Music Thank you. So, if you have not seen the previous video, the link in the i button.\nstart_time: 44.88\nend_time: 70.03', metadata={'source': 'metaclass.csv', 'row': 7}),
#  Document(page_content='text: And in the previous video, I have discussed about the Python decoders and how we can utilize\nstart_time: 70.03\nend_time: 73.91', metadata={'source': 'metaclass.csv', 'row': 8}),
#  Document(page_content='text: these decoders and basically the coding part I have discussed.\nstart_time: 73.91\nend_time: 77.75', metadata={'source': 'metaclass.csv', 'row': 9}),
#  Document(page_content='text: So just refer the video in the i button and I have uploaded the code in the GitHub also you can refer that also. So, just\nstart_time: 77.75\nend_time: 87.0', metadata={'source': 'metaclass.csv', 'row': 10}),
#  Document(page_content='text: note this repository ok. node desipository.\nstart_time: 87.24\nend_time: 89.35', metadata={'source': 'metaclass.csv', 'row': 11}),
#  Document(page_content='text: Okay, node desipository I will be uploading all the materials and notes here in this repository itself.\nstart_time: 89.35\nend_time: 98.77', metadata={'source': 'metaclass.csv', 'row': 12}),
#  Document(page_content='text: Fine.\nstart_time: 98.77\nend_time: 99.77', metadata={'source': 'metaclass.csv', 'row': 13}),
#  Document(page_content="text: So now if I just go to the Python's official documentation. So as you can see this is the Python's official\nstart_time: 99.77\nend_time: 105.0", metadata={'source': 'metaclass.csv', 'row': 14}),
#  Document(page_content='text: documentation. So they have written something in meta classes.\nstart_time: 105.0\nend_time: 108.91', metadata={'source': 'metaclass.csv', 'row': 15}),
#  Document(page_content='text: So what are meta classes actually?\nstart_time: 108.91\nend_time: 110.81', metadata={'source': 'metaclass.csv', 'row': 16}),
#  Document(page_content='text: So by default classes are constructed using type.\nstart_time: 110.81\nend_time: 114.95', metadata={'source': 'metaclass.csv', 'row': 17}),
#  Document(page_content='text: So the type we check like to check any kind of data type right. So, this is this\nstart_time: 114.95\nend_time: 121.37', metadata={'source': 'metaclass.csv', 'row': 18}),
#  Document(page_content='text: is why like it happens.\nstart_time: 121.37\nend_time: 123.28', metadata={'source': 'metaclass.csv', 'row': 19}),
#  Document(page_content='text: So, by default classes are constructed using type ok.\nstart_time: 123.28\nend_time: 127.24', metadata={'source': 'metaclass.csv', 'row': 20}),
#  Document(page_content='text: The class body is executed in a new namespace and the class name is bound locally to the result\nstart_time: 127.24\nend_time: 132.87', metadata={'source': 'metaclass.csv', 'row': 21}),
#  Document(page_content='text: of type name basis and name spaces. So, these things I will be discussing later. So, let us\nstart_time: 132.87\nend_time: 140.21', metadata={'source': 'metaclass.csv', 'row': 22}),
#  Document(page_content='text: just see the example here.\nstart_time: 140.21\nend_time: 142.68', metadata={'source': 'metaclass.csv', 'row': 23}),
#  Document(page_content='text: So the class creation process can be customized by passing the meta class keyword argument in\nstart_time: 142.68\nend_time: 147.88', metadata={'source': 'metaclass.csv', 'row': 24}),
#  Document(page_content='text: the class definition line or by inheriting from an existing class that included\nstart_time: 147.88\nend_time: 153.67', metadata={'source': 'metaclass.csv', 'row': 25}),
#  Document(page_content='text: such an argument. So in the following example, both my class and my subclass are\nstart_time: 153.67\nend_time: 158.47', metadata={'source': 'metaclass.csv', 'row': 26}),
#  Document(page_content='text: instances of meta. Now, let us see. So, as you can see the meta is the meta class and they have inherited the\nstart_time: 158.47\nend_time: 165.56', metadata={'source': 'metaclass.csv', 'row': 27}),
#  Document(page_content='text: type class.\nstart_time: 165.56\nend_time: 166.56', metadata={'source': 'metaclass.csv', 'row': 28}),
#  Document(page_content='text: So, type is also a class in Python. So, they are first for created a meta class by\nstart_time: 166.56\nend_time: 172.17', metadata={'source': 'metaclass.csv', 'row': 29}),
#  Document(page_content='text: inheriting the type class and then they have created a class including the meta class as meta. So, this they have created then they have united the my class into\nstart_time: 172.17\nend_time: 186.06', metadata={'source': 'metaclass.csv', 'row': 30}),
#  Document(page_content='text: my subclass. This is a simple example.\nstart_time: 186.06\nend_time: 189.71', metadata={'source': 'metaclass.csv', 'row': 31}),
#  Document(page_content='text: So by this definition you can say one thing, let us suppose if we are defining some function just that is a single object, but if you are\nstart_time: 189.71\nend_time: 199.73', metadata={'source': 'metaclass.csv', 'row': 32}),
#  Document(page_content='text: building a class,, all the class methods and all the things are basically structured by the\nstart_time: 199.73\nend_time: 207.76', metadata={'source': 'metaclass.csv', 'row': 33}),
#  Document(page_content='text: class itself. And the class itself and the class itself is structured by a class called type\nstart_time: 207.76\nend_time: 214.27', metadata={'source': 'metaclass.csv', 'row': 34}),
#  Document(page_content='text: in Python. So, in simple words, so type is the meta class in Python,\nstart_time: 214.27\nend_time: 220.33', metadata={'source': 'metaclass.csv', 'row': 35}),
#  Document(page_content='text: all the Python classes are using type as default Metaclash.\nstart_time: 220.33\nend_time: 224.32', metadata={'source': 'metaclass.csv', 'row': 36}),
#  Document(page_content='text: So, that is a thing.\nstart_time: 224.32\nend_time: 225.32', metadata={'source': 'metaclass.csv', 'row': 37}),
#  Document(page_content='text: So, in simple words you can say Metacl class is it class of a class that defines how a class will behave.\nstart_time: 225.32\nend_time: 233.67', metadata={'source': 'metaclass.csv', 'row': 38}),
#  Document(page_content='text: So, in Python by default the type is the meta class of every class that we create, but\nstart_time: 233.67\nend_time: 239.13', metadata={'source': 'metaclass.csv', 'row': 39}),
#  Document(page_content='text: you can create your custom meta classes also.\nstart_time: 239.13\nend_time: 241.57', metadata={'source': 'metaclass.csv', 'row': 40}),
#  Document(page_content='text: So, the thing is like in Python you know like a class defines how the\nstart_time: 241.57\nend_time: 248.0', metadata={'source': 'metaclass.csv', 'row': 41}),
#  Document(page_content='text: instance of the class will be treated or maybe how the instance of the class will\nstart_time: 248.0\nend_time: 252.73', metadata={'source': 'metaclass.csv', 'row': 42}),
#  Document(page_content='text: be working right.\nstart_time: 252.73\nend_time: 254.57', metadata={'source': 'metaclass.csv', 'row': 43}),
#  Document(page_content='text: So same way, a meta class is a class of a class. So, this meta class is\nstart_time: 254.57\nend_time: 259.33', metadata={'source': 'metaclass.csv', 'row': 44}),
#  Document(page_content='text: defines how the class will act or be f right. So, this is the basically this is the philosophy of\nstart_time: 259.33\nend_time: 266.36', metadata={'source': 'metaclass.csv', 'row': 45}),
#  Document(page_content='text: meta classes. So, now let us jump into the coding part.\nstart_time: 266.36\nend_time: 270.99', metadata={'source': 'metaclass.csv', 'row': 46}),
#  Document(page_content="text: So, let us now see what are the things we are going to cover in this today's video.\nstart_time: 270.99\nend_time: 276.81", metadata={'source': 'metaclass.csv', 'row': 47}),
#  Document(page_content="text: So first of all there will be introduction to Python Metaclasses and then we'll be talking about how everything in Python is an object that will be creating some Python classes or maybe functions. So and we'll see how these things are being\nstart_time: 276.81\nend_time: 293.48", metadata={'source': 'metaclass.csv', 'row': 48}),
#  Document(page_content='text: an opposite to python. And allocation single memory for every object. So that also\nstart_time: 293.48\nend_time: 299.21', metadata={'source': 'metaclass.csv', 'row': 49}),
#  Document(page_content='text: we will go into see and then we will prove something proof type is the meta class for every Poisson class\nstart_time: 299.21\nend_time: 305.88', metadata={'source': 'metaclass.csv', 'row': 50}),
#  Document(page_content='text: how we are going to see this how the like we are saying that type is a meta class of every class that we create,\nstart_time: 305.88\nend_time: 311.38', metadata={'source': 'metaclass.csv', 'row': 51}),
#  Document(page_content='text: but how. So, that thing we will be proving there. And then there is the fourth point create classes dynamically with\nstart_time: 311.38\nend_time: 319.05', metadata={'source': 'metaclass.csv', 'row': 52}),
#  Document(page_content='text: type as meta class.\nstart_time: 319.05\nend_time: 320.05', metadata={'source': 'metaclass.csv', 'row': 53}),
#  Document(page_content='text: So, the way we create classes, the class then the class name.\nstart_time: 320.05\nend_time: 323.8', metadata={'source': 'metaclass.csv', 'row': 54}),
#  Document(page_content='text: So, then we just construct the class.\nstart_time: 323.8\nend_time: 326.6', metadata={'source': 'metaclass.csv', 'row': 55}),
#  Document(page_content='text: So, we will be just creating the class with the type as a meter class dynamically, okay,\nstart_time: 326.6\nend_time: 333.1', metadata={'source': 'metaclass.csv', 'row': 56}),
#  Document(page_content='text: not with the like structured way that we really follow ok. And same thing we will be doing dynamic\nstart_time: 333.1\nend_time: 340.09', metadata={'source': 'metaclass.csv', 'row': 57}),
#  Document(page_content='text: inheritance with type meta class. So, it is kind of fun you can say or maybe some creative\nstart_time: 340.09\nend_time: 344.4', metadata={'source': 'metaclass.csv', 'row': 58}),
#  Document(page_content='text: ways to create classes or maybe those things. So, these things will be you can take care of, so dynamic inheritance with type meta class. So, then we will be explaining some of the magic methods like underscore\nstart_time: 344.4\nend_time: 359.99', metadata={'source': 'metaclass.csv', 'row': 59}),
#  Document(page_content='text: class, underscore. So, class method and these things will be explaining. And finally,\nstart_time: 359.99\nend_time: 366.32', metadata={'source': 'metaclass.csv', 'row': 60}),
#  Document(page_content='text: we will be creating some custom meta classes. We will see how to create custom meta classes and when to use\nstart_time: 366.32\nend_time: 371.22', metadata={'source': 'metaclass.csv', 'row': 61}),
#  Document(page_content='text: these things so that thing will be covering in this 7th point And then in 8th point we will be using the new and init methods. What\nstart_time: 371.22\nend_time: 380.33', metadata={'source': 'metaclass.csv', 'row': 62}),
#  Document(page_content='text: are the differences between new and init it and how we can utilize them both new and\nstart_time: 380.33\nend_time: 384.64', metadata={'source': 'metaclass.csv', 'row': 63}),
#  Document(page_content='text: in it and the differences and similarities between them. Okay. So these these things are covering this 8 point and finally, the call method and\nstart_time: 384.64\nend_time: 393.26', metadata={'source': 'metaclass.csv', 'row': 64}),
#  Document(page_content='text: its uses. So, it is very useful.\nstart_time: 393.26\nend_time: 395.65', metadata={'source': 'metaclass.csv', 'row': 65}),
#  Document(page_content='text: Okay so how Python takes this call method.\nstart_time: 395.65\nend_time: 400.41', metadata={'source': 'metaclass.csv', 'row': 66}),
#  Document(page_content='text: So these things will be taking care of in this ninth point.\nstart_time: 400.41\nend_time: 403.32', metadata={'source': 'metaclass.csv', 'row': 67}),
#  Document(page_content='text: And finally, in tenth point we will be doing something called single-tone design with\nstart_time: 403.32\nend_time: 408.0', metadata={'source': 'metaclass.csv', 'row': 68}),
#  Document(page_content='text: metaclasm python. single ton design with Metaclash in Python. Single ton design means like a class can have\nstart_time: 408.0\nend_time: 413.18', metadata={'source': 'metaclass.csv', 'row': 69}),
#  Document(page_content='text: only one instance. So, things, you can see here, singleton is a creational design pattern\nstart_time: 413.18\nend_time: 418.89', metadata={'source': 'metaclass.csv', 'row': 70}),
#  Document(page_content='text: which ensures that only one object of its kind exists and provides a single point of access to it for any other\nstart_time: 418.89\nend_time: 425.12', metadata={'source': 'metaclass.csv', 'row': 71}),
#  Document(page_content='text: code.\nstart_time: 425.12\nend_time: 426.12', metadata={'source': 'metaclass.csv', 'row': 72}),
#  Document(page_content='text: So, this is called single term.\nstart_time: 426.12\nend_time: 427.56', metadata={'source': 'metaclass.csv', 'row': 73}),
#  Document(page_content='text: So, this thing will be covering how to create singleton design with Metaclas\nstart_time: 427.56\nend_time: 431.38', metadata={'source': 'metaclass.csv', 'row': 74}),
#  Document(page_content='text: in Python. Okay, I hope this is pretty clear. What and all things we are going to cover in this video.\nstart_time: 431.38\nend_time: 436.69', metadata={'source': 'metaclass.csv', 'row': 75}),
#  Document(page_content="text: Okay, so let's now proceed with the practical part of meta classes, okay. So what and all things we are going to cover? Scope in paste, 1, 1,\nstart_time: 436.69\nend_time: 445.08", metadata={'source': 'metaclass.csv', 'row': 76}),
#  Document(page_content='text: 1, we will see here. So, first thing first, so introduction to pattern metacloss is completed I guess as you can see. So, in python what is\nstart_time: 445.08\nend_time: 461.49', metadata={'source': 'metaclass.csv', 'row': 77}),
#  Document(page_content='text: a metacloss if I say this revision?\nstart_time: 461.49\nend_time: 463.96', metadata={'source': 'metaclass.csv', 'row': 78}),
#  Document(page_content='text: A Metacloss is a class that defines the behavior and structure of other classes, ok.\nstart_time: 463.96\nend_time: 467.6', metadata={'source': 'metaclass.csv', 'row': 79}),
#  Document(page_content='text: It is quite simple, guess often referred to as class factories. In simple terms a meta\nstart_time: 467.6\nend_time: 473.5', metadata={'source': 'metaclass.csv', 'row': 80}),
#  Document(page_content='text: class is a class for classes, just as a class defines the behavior and attributes\nstart_time: 473.5\nend_time: 478.57', metadata={'source': 'metaclass.csv', 'row': 81}),
#  Document(page_content='text: of each instances of that class.\nstart_time: 478.57\nend_time: 481.45', metadata={'source': 'metaclass.csv', 'row': 82}),
#  Document(page_content='text: And similarly, a meta class defense behavior of attribute soft classes ok same thing.\nstart_time: 481.45\nend_time: 487.84', metadata={'source': 'metaclass.csv', 'row': 83}),
#  Document(page_content='text: So, some of the key points to understand our meta classes in Python are everything in Python is an opposite right In Python classes themselves are objects. They are instances of meta classes,\nstart_time: 487.84\nend_time: 499.01', metadata={'source': 'metaclass.csv', 'row': 84}),
#  Document(page_content='text: ok. So, a class is the instance of metaclasses and let us suppose you create some instance of classes that means you define a class and then you just pass it to the like this you can say\nstart_time: 499.01\nend_time: 511.98', metadata={'source': 'metaclass.csv', 'row': 85}),
#  Document(page_content='text: this example there is a class right. So, we are just creating an object. So, this is the instance of the class right.\nstart_time: 511.98\nend_time: 518.61', metadata={'source': 'metaclass.csv', 'row': 86}),
#  Document(page_content='text: Similarly, a class is the instance of meta class. So, this is the meta class see. So, the my class is the instance of my meta,\nstart_time: 518.61\nend_time: 526.48', metadata={'source': 'metaclass.csv', 'row': 87}),
#  Document(page_content='text: okay fine, okay.\nstart_time: 526.48\nend_time: 529.06', metadata={'source': 'metaclass.csv', 'row': 88}),
#  Document(page_content='text: Now customizing class creation.\nstart_time: 529.06\nend_time: 530.9', metadata={'source': 'metaclass.csv', 'row': 89}),
#  Document(page_content='text: So what we can do, key, meta classes allow you to customize how classes are created.\nstart_time: 530.9\nend_time: 536.55', metadata={'source': 'metaclass.csv', 'row': 90}),
#  Document(page_content='text: You can intervene the class creation process, modify attributes and methods and or you can enforce coding standards for classes.\nstart_time: 536.55\nend_time: 545.44', metadata={'source': 'metaclass.csv', 'row': 91}),
#  Document(page_content='text: Okay fine and the third thing is key inheritance chain.\nstart_time: 545.44\nend_time: 549.98', metadata={'source': 'metaclass.csv', 'row': 92}),
#  Document(page_content='text: In Python class creation is often controlled by an inheritance chain.\nstart_time: 549.98\nend_time: 553.94', metadata={'source': 'metaclass.csv', 'row': 93}),
#  Document(page_content='text: When you define a class it inherits properties and methods from its base class, usually object\nstart_time: 553.94\nend_time: 560.49', metadata={'source': 'metaclass.csv', 'row': 94}),
#  Document(page_content='text: or other classes. So meta, metaclasses can affect this inheritance chain you can do\nstart_time: 560.49\nend_time: 564.96', metadata={'source': 'metaclass.csv', 'row': 95}),
#  Document(page_content='text: this. So, these things are key points actually. And it is a simple example how we can create Metaglass, but we will\nstart_time: 564.96\nend_time: 571.34', metadata={'source': 'metaclass.csv', 'row': 96}),
#  Document(page_content='text: see in the next like we will see in the later one, we will see later in this tutorial. So, do not get worried\nstart_time: 571.34\nend_time: 580.73', metadata={'source': 'metaclass.csv', 'row': 97}),
#  Document(page_content='text: about this. So, just let us get started from the second point. So, introduction is done. Now we will see how everything in Python is an object.\nstart_time: 580.73\nend_time: 592.66', metadata={'source': 'metaclass.csv', 'row': 98}),
#  Document(page_content='text: How? Okay. So just say keep in Python everything is an object, everything is an object, so class,\nstart_time: 592.66\nend_time: 597.73', metadata={'source': 'metaclass.csv', 'row': 99}),
#  Document(page_content="text: functions and variables, whatever we define, everything is an object in Python.. So let's just see it how it is happening. Let\nstart_time: 597.73\nend_time: 604.44", metadata={'source': 'metaclass.csv', 'row': 100}),
#  Document(page_content="text: you know create a class okay. Let's simple class. So first one, first point is how everything is Python is not object. it. Thank you. Okay, so we'll create a simple class named like let us suppose a, b, c and this simple whatever just print on maybe just pass it better.\nstart_time: 604.44\nend_time: 652.74", metadata={'source': 'metaclass.csv', 'row': 101}),
#  Document(page_content="text: Now let's create an instance of this abc ... So now we have created the class simple thing and we have just created an instance of this class right. So if I just print the class now\nstart_time: 652.74\nend_time: 672.78", metadata={'source': 'metaclass.csv', 'row': 102}),
#  Document(page_content='text: instance sorry if I just print the instance now. So you can see it has created some option right and this is some unusual numbers.\nstart_time: 672.78\nend_time: 686.0', metadata={'source': 'metaclass.csv', 'row': 103}),
#  Document(page_content='text: So what are these things?\nstart_time: 686.0\nend_time: 688.0', metadata={'source': 'metaclass.csv', 'row': 104}),
#  Document(page_content='text: So this thing is actually showing the memory location of the instance ABC and this is the hexadecimal number actually. So, it is a unique location id for each and only of the object. So you just create anything and then\nstart_time: 688.0\nend_time: 708.0', metadata={'source': 'metaclass.csv', 'row': 105}),
#  Document(page_content='text: we will have this ID in your memory. Okay, so I hope this is clear. And similarly you can say you can see see everything is an option in Python.\nstart_time: 708.0\nend_time: 717.53', metadata={'source': 'metaclass.csv', 'row': 106}),
#  Document(page_content='text: Okay, same thing I just create a function. So we just print. So, this is the function and this is the memory location right.\nstart_time: 717.83\nend_time: 746.32', metadata={'source': 'metaclass.csv', 'row': 107}),
#  Document(page_content='text: So, everything in Python seems to be an object right. So this is the point when you can say\nstart_time: 746.32\nend_time: 752.74', metadata={'source': 'metaclass.csv', 'row': 108}),
#  Document(page_content="text: this. Let's move to the next point.\nstart_time: 752.74\nend_time: 756.13", metadata={'source': 'metaclass.csv', 'row': 109}),
#  Document(page_content='text: So proof type is the meta class for every Python class.\nstart_time: 756.13\nend_time: 759.17', metadata={'source': 'metaclass.csv', 'row': 110}),
#  Document(page_content='text: How we are going to see?\nstart_time: 759.17\nend_time: 760.17', metadata={'source': 'metaclass.csv', 'row': 111}),
#  Document(page_content="text: Let's see. So as we can say we have created the class write ABC.\nstart_time: 760.17\nend_time: 765.16", metadata={'source': 'metaclass.csv', 'row': 112}),
#  Document(page_content='text: So, that same example we will talking about ABC. So, ABC is the instance of ABC right. Yep. So, if I just print abc just type and then just print it.\nstart_time: 765.16\nend_time: 778.01', metadata={'source': 'metaclass.csv', 'row': 113}),
#  Document(page_content='text: So, you will see key main.abc that means main is this module whatever this notebook is and dot abc abc is a class of\nstart_time: 778.01\nend_time: 785.2', metadata={'source': 'metaclass.csv', 'row': 114}),
#  Document(page_content='text: this ok.\nstart_time: 785.2\nend_time: 786.72', metadata={'source': 'metaclass.csv', 'row': 115}),
#  Document(page_content='text: So, you just say, us suppose ABC dot underscore class, anyhow we will see the class letter, but let us see what it does actually.\nstart_time: 786.72\nend_time: 800.33', metadata={'source': 'metaclass.csv', 'row': 116}),
#  Document(page_content='text: It actually gives you the class names of the instance.\nstart_time: 800.33\nend_time: 803.2', metadata={'source': 'metaclass.csv', 'row': 117}),
#  Document(page_content='text: Similarly, if I just run same thing again class, so here I will see I will show you one thing ok. So, what happens here we just\nstart_time: 803.2\nend_time: 814.86', metadata={'source': 'metaclass.csv', 'row': 118}),
#  Document(page_content='text: getting type, why type. So, if I just remove this so we get\nstart_time: 814.86\nend_time: 820.15', metadata={'source': 'metaclass.csv', 'row': 119}),
#  Document(page_content='text: a bc right and abc instance of something and that something is type.\nstart_time: 820.15\nend_time: 838.29', metadata={'source': 'metaclass.csv', 'row': 120}),
#  Document(page_content='text: Got it.\nstart_time: 838.29\nend_time: 839.29', metadata={'source': 'metaclass.csv', 'row': 121}),
#  Document(page_content='text: So this small case abc is the instant of abc class, right this one. So, we are getting the\nstart_time: 839.29\nend_time: 846.25', metadata={'source': 'metaclass.csv', 'row': 122}),
#  Document(page_content='text: abc and the abc is an instance of type that is why you are getting type.\nstart_time: 846.25\nend_time: 851.26', metadata={'source': 'metaclass.csv', 'row': 123}),
#  Document(page_content='text: So it is funny I know but it is somehow misleads us to know what type actually is. So, let us see what type actually is.\nstart_time: 851.26\nend_time: 860.33', metadata={'source': 'metaclass.csv', 'row': 124}),
#  Document(page_content='text: So, if I just check one thing type of let us suppose ABC is an instance right.\nstart_time: 860.33\nend_time: 865.49', metadata={'source': 'metaclass.csv', 'row': 125}),
#  Document(page_content="text: So, it will give us ABC is the ABC class right. it's an instance of abc class so that is how you're getting abc it's\nstart_time: 865.49\nend_time: 872.3", metadata={'source': 'metaclass.csv', 'row': 126}),
#  Document(page_content="text: fine no magic here but if I just check a b c it's the class name right it's a class name\nstart_time: 872.3\nend_time: 880.13", metadata={'source': 'metaclass.csv', 'row': 127}),
#  Document(page_content='text: see if I just check this type, we are getting type.\nstart_time: 880.13\nend_time: 883.91', metadata={'source': 'metaclass.csv', 'row': 128}),
#  Document(page_content='text: So same thing if you just refer to my video, any of the video link in other video link of this explanation is on the i button, is on the i button, go check\nstart_time: 883.91\nend_time: 893.66', metadata={'source': 'metaclass.csv', 'row': 129}),
#  Document(page_content='text: it out.\nstart_time: 893.66\nend_time: 894.66', metadata={'source': 'metaclass.csv', 'row': 130}),
#  Document(page_content="text: So, go check it out ok otherwise you can see so we can say key let us suppose we can write it here. So abc is an instance of a BC class right similarly. Similarly, ABC class, if the actually can say FD class that we create is an instance of a Metacloss in Python it is by default is an instance of type. Now same thing if I just check type of type it's funny. It is funny let us see again we are getting type that means type itself is a meta class\nstart_time: 894.66\nend_time: 967.95", metadata={'source': 'metaclass.csv', 'row': 131}),
#  Document(page_content='text: of type class right. So, same thing same diagram if you just follow\nstart_time: 967.95\nend_time: 973.66', metadata={'source': 'metaclass.csv', 'row': 132}),
#  Document(page_content='text: go to the first video of this playlist you can see this.\nstart_time: 974.22\nend_time: 977.01', metadata={'source': 'metaclass.csv', 'row': 133}),
#  Document(page_content='text: Okay, so how this is happening, we are not going to go into the much deeper because that is not our task here. So this is why\nstart_time: 977.01\nend_time: 986.71', metadata={'source': 'metaclass.csv', 'row': 134}),
#  Document(page_content='text: you can say key type is a meta class for every class that you create in python right\nstart_time: 986.71\nend_time: 990.66', metadata={'source': 'metaclass.csv', 'row': 135}),
#  Document(page_content='text: or if I just create a new single other class or maybe we can import something right, import pandas maybe. So now if I just import\nstart_time: 990.66\nend_time: 999.25', metadata={'source': 'metaclass.csv', 'row': 136}),
#  Document(page_content='text: pd, just import in So, it is important to check the type of PD.\nstart_time: 1001.49\nend_time: 1006.99', metadata={'source': 'metaclass.csv', 'row': 137}),
#  Document(page_content='text: It is a module right?\nstart_time: 1006.99\nend_time: 1010.42', metadata={'source': 'metaclass.csv', 'row': 138}),
#  Document(page_content='text: So just have to create a call class.\nstart_time: 1010.42\nend_time: 1013.54', metadata={'source': 'metaclass.csv', 'row': 139}),
#  Document(page_content="text: Let's suppose pd.datafrim maybe data will be I for I range 10 okay we got it right. So, let us suppose it says something df ok and if I just create a type of DF, we is a data frame right. Now if I just check the type of this one, data frame. So, data frame is a class, right?\nstart_time: 1013.54\nend_time: 1056.09", metadata={'source': 'metaclass.csv', 'row': 140}),
#  Document(page_content='text: So, now if I just check the type of data frame, right?\nstart_time: 1056.09\nend_time: 1061.57', metadata={'source': 'metaclass.csv', 'row': 141}),
#  Document(page_content="text: So, isn't it is Amazon right. Whatever class we have and whatever class we are creating\nstart_time: 1061.57\nend_time: 1066.79", metadata={'source': 'metaclass.csv', 'row': 142}),
#  Document(page_content='text: that is by default the instance of the type meta class. So, this is how meta class is a\nstart_time: 1066.79\nend_time: 1072.18', metadata={'source': 'metaclass.csv', 'row': 143}),
#  Document(page_content='text: single entity for a free class that you create in Python right. So, what if we could create our own meta class?\nstart_time: 1072.18\nend_time: 1077.89', metadata={'source': 'metaclass.csv', 'row': 144}),
#  Document(page_content='text: So, that will be much more beneficial for our use cases sometimes not every time. So, that is the thing, but yeah. So, but in this way we can say key type is the meta class for every class that we create in Python.\nstart_time: 1077.89\nend_time: 1090.82', metadata={'source': 'metaclass.csv', 'row': 145}),
#  Document(page_content='text: Right.\nstart_time: 1090.82\nend_time: 1091.82', metadata={'source': 'metaclass.csv', 'row': 146}),
#  Document(page_content='text: Okay.\nstart_time: 1091.82\nend_time: 1092.82', metadata={'source': 'metaclass.csv', 'row': 147}),
#  Document(page_content='text: Fine.\nstart_time: 1092.82\nend_time: 1093.82', metadata={'source': 'metaclass.csv', 'row': 148}),
#  Document(page_content="text: So let's move to the next point.\nstart_time: 1093.82\nend_time: 1094.82", metadata={'source': 'metaclass.csv', 'row': 149}),
#  Document(page_content="text: So next point is create classes dynamically with type as a meta class. So let's\nstart_time: 1094.82\nend_time: 1100.03", metadata={'source': 'metaclass.csv', 'row': 150}),
#  Document(page_content='text: me just write it first. So, how usually we create the Python classes this way right this\nstart_time: 1100.03\nend_time: 1107.95', metadata={'source': 'metaclass.csv', 'row': 151}),
#  Document(page_content='text: is the Python class and we just simply just write something called\nstart_time: 1107.95\nend_time: 1112.1', metadata={'source': 'metaclass.csv', 'row': 152}),
#  Document(page_content='text: underscore init and just we pass something right. So, these things we have been doing since we have been introduced\nstart_time: 1112.1\nend_time: 1119.13', metadata={'source': 'metaclass.csv', 'row': 153}),
#  Document(page_content="text: to Python right. But there might be some other ways to do it right how so let's see it how we are going to create classes dynamically with type as a meta class. So let us now see how we can create\nstart_time: 1119.13\nend_time: 1131.72", metadata={'source': 'metaclass.csv', 'row': 154}),
#  Document(page_content='text: the classes dynamically with Python. So usually we create Python classes like this right. So, we define some class and we define\nstart_time: 1131.72\nend_time: 1140.33', metadata={'source': 'metaclass.csv', 'row': 155}),
#  Document(page_content='text: some unit methods and maybe constructors whatever. So, just create classes in this\nstart_time: 1140.33\nend_time: 1145.71', metadata={'source': 'metaclass.csv', 'row': 156}),
#  Document(page_content='text: way right and then we create some instance of it and then we access the functionalities or methods right.\nstart_time: 1145.71\nend_time: 1150.34', metadata={'source': 'metaclass.csv', 'row': 157}),
#  Document(page_content='text: So, this is the usual way we deal with Python classes right, but what if I tell you you there is other ways to create classes dynamically.\nstart_time: 1150.34\nend_time: 1158.33', metadata={'source': 'metaclass.csv', 'row': 158}),
#  Document(page_content="text: So let's suppose there is a class and I am creating a, let us just to give you the similarity. So, this is the class\nstart_time: 1158.33\nend_time: 1166.07", metadata={'source': 'metaclass.csv', 'row': 159}),
#  Document(page_content='text: of a, or maybe like like, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, ah, like, fong or maybe custom class, okay.\nstart_time: 1166.07\nend_time: 1174.26', metadata={'source': 'metaclass.csv', 'row': 160}),
#  Document(page_content="text: Okay. So this is a custom class and we are just passing whatever we don't need anything.\nstart_time: 1174.26\nend_time: 1179.71", metadata={'source': 'metaclass.csv', 'row': 161}),
#  Document(page_content='text: So CLS is equal to custom class and we just print cls we will get to know what is it, it is an instance of custom class right same way ok if we just comment it out ok.\nstart_time: 1179.71\nend_time: 1199.01', metadata={'source': 'metaclass.csv', 'row': 162}),
#  Document(page_content='text: So, now if we just do one thing same thing we are going to do. So what is the name of the class?\nstart_time: 1199.01\nend_time: 1204.31', metadata={'source': 'metaclass.csv', 'row': 163}),
#  Document(page_content="text: Custom plus right? Let's get a variable and then we'll be passing the type meta class here.\nstart_time: 1204.31\nend_time: 1213.02", metadata={'source': 'metaclass.csv', 'row': 164}),
#  Document(page_content='text: Okay.\nstart_time: 1213.02\nend_time: 1214.02', metadata={'source': 'metaclass.csv', 'row': 165}),
#  Document(page_content='text: And what is the name of the class?\nstart_time: 1214.02\nend_time: 1215.33', metadata={'source': 'metaclass.csv', 'row': 166}),
#  Document(page_content="text: Let's suppose this is the name, right?\nstart_time: 1215.33\nend_time: 1217.33", metadata={'source': 'metaclass.csv', 'row': 167}),
#  Document(page_content="text: It's a powerful name.\nstart_time: 1217.33\nend_time: 1219.33", metadata={'source': 'metaclass.csv', 'row': 168}),
#  Document(page_content='text: Okay, so the type meta class takes three arguments, one is the class name, in strings and then\nstart_time: 1219.33\nend_time: 1227.99', metadata={'source': 'metaclass.csv', 'row': 169}),
#  Document(page_content='text: we will get to pass.\nstart_time: 1227.99\nend_time: 1232.66', metadata={'source': 'metaclass.csv', 'row': 170}),
#  Document(page_content="text: If we are doing any inheritance, we will pass this otherwise we will keep it blank in parenthesis okay. I'll show\nstart_time: 1232.66\nend_time: 1237.73", metadata={'source': 'metaclass.csv', 'row': 171}),
#  Document(page_content="text: you when next mind when you create some inheritance and then we'll pass the parameters. So if you have any parameters, we can pass it as\nstart_time: 1237.73\nend_time: 1244.49", metadata={'source': 'metaclass.csv', 'row': 172}),
#  Document(page_content='text: dictionaries otherwise just skip it blank. Okay. Okay. So now just this is a class we have created okay, so is it funny right can\nstart_time: 1244.49\nend_time: 1254.2', metadata={'source': 'metaclass.csv', 'row': 173}),
#  Document(page_content="text: you create it like can you create a class like this? No, right. We have, so we just create custom class and let's suppose cs cls ok, let us print it and if it is print cls, see it is a offset of custom class, right?\nstart_time: 1254.2\nend_time: 1278.01", metadata={'source': 'metaclass.csv', 'row': 174}),
#  Document(page_content="text: Same thing, let's do one thing, let's pass some attributes, okay.\nstart_time: 1278.01\nend_time: 1281.61", metadata={'source': 'metaclass.csv', 'row': 175}),
#  Document(page_content="text: Let's pass some attributes. Okay.\nstart_time: 1281.61\nend_time: 1281.99", metadata={'source': 'metaclass.csv', 'row': 176}),
#  Document(page_content="text: Let's suppose name and what is my name?\nstart_time: 1281.99\nend_time: 1285.43", metadata={'source': 'metaclass.csv', 'row': 177}),
#  Document(page_content='text: Okay.\nstart_time: 1285.43\nend_time: 1286.43', metadata={'source': 'metaclass.csv', 'row': 178}),
#  Document(page_content='text: We have to give it a strings.\nstart_time: 1286.43\nend_time: 1287.95', metadata={'source': 'metaclass.csv', 'row': 179}),
#  Document(page_content="text: Okay. give it and strings name my name is rjk is right so Okay, so now I will just pass it okay so I want to print the name see so isn't it amazing, right?\nstart_time: 1287.95\nend_time: 1310.5", metadata={'source': 'metaclass.csv', 'row': 180}),
#  Document(page_content='text: So we have just created a class by not using the class keyword, right? So we just have created a class by using only that type meta class right.\nstart_time: 1310.5\nend_time: 1319.81', metadata={'source': 'metaclass.csv', 'row': 181}),
#  Document(page_content='text: So this is how we can create classes also and this is called the dynamic class creation.\nstart_time: 1319.81\nend_time: 1325.75', metadata={'source': 'metaclass.csv', 'row': 182}),
#  Document(page_content='text: So, we can pass any number of parameters we choose, okay, whatever you feel.\nstart_time: 1325.75\nend_time: 1331.34', metadata={'source': 'metaclass.csv', 'row': 183}),
#  Document(page_content="text: Let's suppose you tube channel name.\nstart_time: 1333.18\nend_time: 1340.32", metadata={'source': 'metaclass.csv', 'row': 184}),
#  Document(page_content='text: So what is my YouTube channel?\nstart_time: 1340.32\nend_time: 1341.99', metadata={'source': 'metaclass.csv', 'row': 185}),
#  Document(page_content='text: Which is\nstart_time: 1342.99\nend_time: 1343.99', metadata={'source': 'metaclass.csv', 'row': 186}),
#  Document(page_content='text: AI\nstart_time: 1345.99\nend_time: 1346.99', metadata={'source': 'metaclass.csv', 'row': 187}),
#  Document(page_content="text: and release, left right, pass it, you can pass this thing, see let's start. Obviously, we have to take care of these things should be syntactically correct. right you got it right. So, this is the way we can create classes dynamically in Python with the type meta class\nstart_time: 1347.99\nend_time: 1381.4", metadata={'source': 'metaclass.csv', 'row': 188}),
#  Document(page_content='text: right. Let us move to the next point now. So, it is our next point\nstart_time: 1381.4\nend_time: 1386.99', metadata={'source': 'metaclass.csv', 'row': 189}),
#  Document(page_content='text: dynamic inheritance with type planter class, dynamic inheritance with type meta class.\nstart_time: 1392.16\nend_time: 1393.16', metadata={'source': 'metaclass.csv', 'row': 190}),
#  Document(page_content="text: So let's see how we can use this.\nstart_time: 1393.16\nend_time: 1397.32", metadata={'source': 'metaclass.csv', 'row': 191}),
#  Document(page_content='text: I hope you are having fun learning these things. So, if you just like it, just subscribe to the channel ok. Thanks. So, now let us move to the next point dynamic inheritance\nstart_time: 1397.32\nend_time: 1413.14', metadata={'source': 'metaclass.csv', 'row': 192}),
#  Document(page_content='text: with type Metacloss. How we are going to achieve this. So, we have created a class called custom\nstart_time: 1413.14\nend_time: 1419.08', metadata={'source': 'metaclass.csv', 'row': 193}),
#  Document(page_content='text: class, right. So, we have to inherit this class, let us suppose. So, now create the same kind of thing, just\nstart_time: 1419.08\nend_time: 1425.59', metadata={'source': 'metaclass.csv', 'row': 194}),
#  Document(page_content="text: copy it and paste it. So, I will change the name custom class let's suppose 0 1 okay and it will\nstart_time: 1426.39\nend_time: 1434.42", metadata={'source': 'metaclass.csv', 'row': 195}),
#  Document(page_content='text: be 0 1 and we will inherit it in this time.\nstart_time: 1434.42\nend_time: 1437.84', metadata={'source': 'metaclass.csv', 'row': 196}),
#  Document(page_content="text: So we have to give the class name custom class done. So, we will call the class name and we pass some other parameters, let's suppose, h, so I am 23 and let us suppose whatever. whatever job okay so I'll just do it. industry data, send, test, okay.\nstart_time: 1437.84\nend_time: 1470.86", metadata={'source': 'metaclass.csv', 'row': 197}),
#  Document(page_content='text: Let me say experience two.\nstart_time: 1474.1\nend_time: 1480.32', metadata={'source': 'metaclass.csv', 'row': 198}),
#  Document(page_content='text: Never just pass, just call this, why this?\nstart_time: 1480.32\nend_time: 1492.98', metadata={'source': 'metaclass.csv', 'row': 199}),
#  Document(page_content='text: So, why this error has come?\nstart_time: 1492.98\nend_time: 1495.32', metadata={'source': 'metaclass.csv', 'row': 200}),
#  Document(page_content='text: Let us see.\nstart_time: 1495.32\nend_time: 1496.32', metadata={'source': 'metaclass.csv', 'row': 201}),
#  Document(page_content='text: So, in Python, if you just have to create a tuple with a single element, right? So, we have to create a tuple with a single element right so we have to pass a trailing comma otherwise\nstart_time: 1496.32\nend_time: 1505.75', metadata={'source': 'metaclass.csv', 'row': 202}),
#  Document(page_content="text: the python wouldn't take it as a tuple, single element tuple.\nstart_time: 1505.75\nend_time: 1509.84", metadata={'source': 'metaclass.csv', 'row': 203}),
#  Document(page_content='text: So this is a syntactical like requirement we have to pass, just trailing comma we have\nstart_time: 1509.84\nend_time: 1514.94', metadata={'source': 'metaclass.csv', 'row': 204}),
#  Document(page_content='text: to pass. Okay, so after the class, we have to pass a trailing\nstart_time: 1514.94\nend_time: 1519.04', metadata={'source': 'metaclass.csv', 'row': 205}),
#  Document(page_content="text: comma. Now, let's run it. Now, there is no way right it has occurred. Now let's see the unit edge is working or not.\nstart_time: 1519.04\nend_time: 1526.63", metadata={'source': 'metaclass.csv', 'row': 206}),
#  Document(page_content='text: CLS 0 1. cls01.c we have everything name, job, experience, age, everything, right. And the magical thing is key.\nstart_time: 1527.11\nend_time: 1538.6', metadata={'source': 'metaclass.csv', 'row': 207}),
#  Document(page_content='text: We have not created any class with the class keyword. Everything I have done with the time meter\nstart_time: 1538.6\nend_time: 1544.51', metadata={'source': 'metaclass.csv', 'row': 208}),
#  Document(page_content='text: class itself. Till so far whatever class we have defined whatever class we have\nstart_time: 1544.51\nend_time: 1547.91', metadata={'source': 'metaclass.csv', 'row': 209}),
#  Document(page_content='text: created, everything we have created with the type meta class.\nstart_time: 1547.91\nend_time: 1551.06', metadata={'source': 'metaclass.csv', 'row': 210}),
#  Document(page_content='text: So this is a new way we can create classes and this is more often easy maybe. So, somehow we can create this pass name,\nstart_time: 1552.1\nend_time: 1560.32', metadata={'source': 'metaclass.csv', 'row': 211}),
#  Document(page_content="text: pass the attributes and if you want to inherit something, they're passing inheritance. Like, pass the parent class name, parent class object actually okay so same thing we have done and if I just call this name we, we don't have anything called name here, right?\nstart_time: 1564.31\nend_time: 1577.24", metadata={'source': 'metaclass.csv', 'row': 212}),
#  Document(page_content='text: Because we have inherited the previous class.\nstart_time: 1577.24\nend_time: 1579.64', metadata={'source': 'metaclass.csv', 'row': 213}),
#  Document(page_content='text: If you just pass the name, we got this from here, right?\nstart_time: 1579.96\nend_time: 1583.47', metadata={'source': 'metaclass.csv', 'row': 214}),
#  Document(page_content='text: We got the YouTube channel, right?\nstart_time: 1583.47\nend_time: 1586.99', metadata={'source': 'metaclass.csv', 'row': 215}),
#  Document(page_content='text: Okay. So we have to take care of the naming conventions. Thank you. We got the attributes of the previous like parent classes right. So, this is somehow, somehow tricky right\nstart_time: 1586.99\nend_time: 1621.0', metadata={'source': 'metaclass.csv', 'row': 216}),
#  Document(page_content='text: and you also. So, we have created classes dynamically with type, we have created inheritance\nstart_time: 1621.0\nend_time: 1627.11', metadata={'source': 'metaclass.csv', 'row': 217}),
#  Document(page_content='text: with type. So, these two things are very much useful and handy when you use python for your projects\nstart_time: 1627.11\nend_time: 1633.58', metadata={'source': 'metaclass.csv', 'row': 218}),
#  Document(page_content='text: on maybe some frameworks or those things. So, let us now move to the next point.\nstart_time: 1633.58\nend_time: 1639.28', metadata={'source': 'metaclass.csv', 'row': 219}),
#  Document(page_content='text: I hope till so far you have understood the points and if you have not, if you have any query, let\nstart_time: 1639.28\nend_time: 1645.07', metadata={'source': 'metaclass.csv', 'row': 220}),
#  Document(page_content='text: me know in the comments.\nstart_time: 1645.07\nend_time: 1646.57', metadata={'source': 'metaclass.csv', 'row': 221}),
#  Document(page_content='text: So now we will explain the 6th point, what is the class method here.\nstart_time: 1646.57\nend_time: 1650.66', metadata={'source': 'metaclass.csv', 'row': 222}),
# ...
#  Document(page_content='text: So, this is the simple class we have created till now right. So, no fancy logic ok. So, now what you can do just\nstart_time: 2970.89\nend_time: 2978.75', metadata={'source': 'metaclass.csv', 'row': 398}),
#  Document(page_content='text: let us create an instance of the class.\nstart_time: 2978.75\nend_time: 2983.44', metadata={'source': 'metaclass.csv', 'row': 399}),
#  Document(page_content='text: So instance or QCl2, call test.\nstart_time: 2983.44\nend_time: 2991.17', metadata={'source': 'metaclass.csv', 'row': 400}),
#  Document(page_content='text: And we need number one and number two.\nstart_time: 2991.17\nend_time: 2992.57', metadata={'source': 'metaclass.csv', 'row': 401}),
#  Document(page_content='text: So number one we pass as suppose 3 and norm 2 we pass as 4. So, now till this part it is fine right we know these things.\nstart_time: 2992.57\nend_time: 3006.46', metadata={'source': 'metaclass.csv', 'row': 402}),
#  Document(page_content='text: Now, what if we are going to so how to call this, just call the instance and we got the\nstart_time: 3006.46\nend_time: 3014.13', metadata={'source': 'metaclass.csv', 'row': 403}),
#  Document(page_content='text: num3 write by default. So num3 right by default.\nstart_time: 3014.13\nend_time: 3016.13', metadata={'source': 'metaclass.csv', 'row': 404}),
#  Document(page_content="text: So num3 we can pass as, let's suppose 10 right?\nstart_time: 3016.13\nend_time: 3021.13", metadata={'source': 'metaclass.csv', 'row': 405}),
#  Document(page_content="text: And we'll get 17 right. So, this is the simple logic actually. So, if you want to make the instance callable, you just pass the call special method in the\nstart_time: 3021.63\nend_time: 3033.31", metadata={'source': 'metaclass.csv', 'row': 406}),
#  Document(page_content='text: class, okay.\nstart_time: 3033.31\nend_time: 3034.31', metadata={'source': 'metaclass.csv', 'row': 407}),
#  Document(page_content='text: While defining the class, you just mention the call my special method. And\nstart_time: 3034.31\nend_time: 3040.07', metadata={'source': 'metaclass.csv', 'row': 408}),
#  Document(page_content='text: then you can just create the instance callable as a callable one.\nstart_time: 3040.07\nend_time: 3043.98', metadata={'source': 'metaclass.csv', 'row': 409}),
#  Document(page_content='text: So this is the way we can do these things so that like it is better to make these things very useful.\nstart_time: 3043.98\nend_time: 3054.29', metadata={'source': 'metaclass.csv', 'row': 410}),
#  Document(page_content='text: So this is all about the call, nothing fancy, but it is so useful actually.\nstart_time: 3054.29\nend_time: 3060.31', metadata={'source': 'metaclass.csv', 'row': 411}),
#  Document(page_content='text: So, that is it. So, let us jump into the next topic. So, let us jump into the next topic\nstart_time: 3060.31\nend_time: 3067.86', metadata={'source': 'metaclass.csv', 'row': 412}),
#  Document(page_content='text: which is our last one that is singleton design with Metacloss.\nstart_time: 3067.86\nend_time: 3072.97', metadata={'source': 'metaclass.csv', 'row': 413}),
#  Document(page_content="text: So before that what is singleton I will you. I think I've shown you that again. I'll show you.\nstart_time: 3072.97\nend_time: 3077.39", metadata={'source': 'metaclass.csv', 'row': 414}),
#  Document(page_content='text: So it shows you, see single con is a creational design pattern which ensures that only one object of its kind exists and provides a single point of access to it for\nstart_time: 3081.47\nend_time: 3094.25', metadata={'source': 'metaclass.csv', 'row': 415}),
#  Document(page_content='text: any other code ok. So, that is the thing. So, let us now code it out. So, this is our last topic.\nstart_time: 3094.25\nend_time: 3105.66', metadata={'source': 'metaclass.csv', 'row': 416}),
#  Document(page_content='text: So, what is this single tone?\nstart_time: 3105.66\nend_time: 3109.13', metadata={'source': 'metaclass.csv', 'row': 417}),
#  Document(page_content='text: So, I told you right.\nstart_time: 3109.13\nend_time: 3111.01', metadata={'source': 'metaclass.csv', 'row': 418}),
#  Document(page_content='text: But one thing like let us suppose you are creating a class right.\nstart_time: 3111.01\nend_time: 3114.69', metadata={'source': 'metaclass.csv', 'row': 419}),
#  Document(page_content='text: So you can create any number of instances, but what if we are not like restrict the user to create only one instance. So, that is called single-tron design. So, let us\nstart_time: 3114.69\nend_time: 3124.78', metadata={'source': 'metaclass.csv', 'row': 420}),
#  Document(page_content='text: create it. The first of all we will see how we should know how many number of instances are being created.\nstart_time: 3124.78\nend_time: 3134.45', metadata={'source': 'metaclass.csv', 'row': 421}),
#  Document(page_content='text: So you can see this but let us suppose let us create a class. Let us create a meta class. We are not implementing here any kind of single-tone design so we will call it not a single-tone. single down\nstart_time: 3134.45\nend_time: 3148.65', metadata={'source': 'metaclass.csv', 'row': 422}),
#  Document(page_content="text: Okay, so we can create a number of instances, but we'll see how many instances we are creating right so that the, let us check it out.\nstart_time: 3148.65\nend_time: 3157.31", metadata={'source': 'metaclass.csv', 'row': 423}),
#  Document(page_content='text: So, we will do one thing, we will introduce a variable called instances and we will store\nstart_time: 3157.31\nend_time: 3160.31', metadata={'source': 'metaclass.csv', 'row': 424}),
#  Document(page_content="text: the node. and we will store the numbers here, numbers and objects and the class names. So these so these things we are showing here and let's just create a call method. method ok.\nstart_time: 3160.31\nend_time: 3176.59", metadata={'source': 'metaclass.csv', 'row': 425}),
#  Document(page_content='text: We need to change it to CSS.\nstart_time: 3176.59\nend_time: 3180.31', metadata={'source': 'metaclass.csv', 'row': 426}),
#  Document(page_content='text: Ok fine, yep. So what we do actually, we will do actually?\nstart_time: 3180.31\nend_time: 3192.15', metadata={'source': 'metaclass.csv', 'row': 427}),
#  Document(page_content='text: So, we will just store it, okay, CLS dot instances equal to and will store CLS here equal to. Thank you. Thank you. So, we will use this and then we will do one thing, we will just print it, we will see how\nstart_time: 3192.15\nend_time: 3245.62', metadata={'source': 'metaclass.csv', 'row': 428}),
#  Document(page_content='text: many instances are being created, so we will see it. Thank you. Now we print it once. Thank you. Okay. will just return simply CLS.instances. So, we will create two classes here.\nstart_time: 3245.62\nend_time: 3304.94', metadata={'source': 'metaclass.csv', 'row': 429}),
#  Document(page_content='text: One is one with this not single tone as the meta class and one more. Not single tone.\nstart_time: 3304.94\nend_time: 3330.01', metadata={'source': 'metaclass.csv', 'row': 430}),
#  Document(page_content="text: Okay, now let's create two objects here. Now, let's run this.\nstart_time: 3330.01\nend_time: 3343.5", metadata={'source': 'metaclass.csv', 'row': 431}),
#  Document(page_content='text: So as you can see, while initializing the first one, we just add one instance because we have created only one instance of it. So we\nstart_time: 3343.5\nend_time: 3351.73', metadata={'source': 'metaclass.csv', 'row': 432}),
#  Document(page_content='text: add this one only one and this is the key and value. So, in key we are just storing the name and value we are\nstart_time: 3351.73\nend_time: 3361.43', metadata={'source': 'metaclass.csv', 'row': 433}),
#  Document(page_content='text: storing the object itself right. So, this is the thing and second one when we are creating the second instance, we are getting the length of 2.\nstart_time: 3361.43\nend_time: 3372.65', metadata={'source': 'metaclass.csv', 'row': 434}),
#  Document(page_content='text: So, we are storing 2 instances here. So, this is how we can like introduce as number of instances as we want. So, by default you can create any number of instances, but if you want to\nstart_time: 3372.65\nend_time: 3386.06', metadata={'source': 'metaclass.csv', 'row': 435}),
#  Document(page_content='text: specify the user like they should not use more than one instances.\nstart_time: 3386.06\nend_time: 3391.53', metadata={'source': 'metaclass.csv', 'row': 436}),
#  Document(page_content='text: So how to use that?\nstart_time: 3391.53\nend_time: 3393.25', metadata={'source': 'metaclass.csv', 'row': 437}),
#  Document(page_content='text: So that is called singleton design. So, we can use this by creating a meta class. So, how\nstart_time: 3393.25\nend_time: 3399.31', metadata={'source': 'metaclass.csv', 'row': 438}),
#  Document(page_content='text: to do that? So, let us do this. So, by default you are allowed to create any number of instances, but\nstart_time: 3399.31\nend_time: 3404.3', metadata={'source': 'metaclass.csv', 'row': 439}),
#  Document(page_content='text: there comes the usability of meta classes right that you are not allowing the user to create more than one instances.\nstart_time: 3405.1\nend_time: 3411.89', metadata={'source': 'metaclass.csv', 'row': 440}),
#  Document(page_content='text: These things you can customize all these things in meta classes. So we have till till now we have just one one instances for each\nstart_time: 3411.89\nend_time: 3418.95', metadata={'source': 'metaclass.csv', 'row': 441}),
#  Document(page_content='text: class. So, I am showing you with a not single ton design. So, there is total two instances of two different classes.\nstart_time: 3418.95\nend_time: 3426.7', metadata={'source': 'metaclass.csv', 'row': 442}),
#  Document(page_content='text: So, one for each. Now Now if I just create 2 more a 1 equal to 1 a 2 equal to 2. So, if it is not a single dot design it will give us all four of them right as you can see. So, before implementing the single-tone design, we have to see how we can create any number of instances of a single class. So, you can create any number\nstart_time: 3426.7\nend_time: 3465.82', metadata={'source': 'metaclass.csv', 'row': 443}),
#  Document(page_content='text: of classes any number of instances right there is no limitation. But what if we are not\nstart_time: 3465.82\nend_time: 3472.44', metadata={'source': 'metaclass.csv', 'row': 444}),
#  Document(page_content='text: restrict the user to create only one instance for each class and not talking about meta class.\nstart_time: 3472.44\nend_time: 3477.39', metadata={'source': 'metaclass.csv', 'row': 445}),
#  Document(page_content='text: So for each class the user is supposed to create only one instance no matter how many\nstart_time: 3477.39\nend_time: 3481.35', metadata={'source': 'metaclass.csv', 'row': 446}),
#  Document(page_content='text: instances they are creating but we are only limiting the\nstart_time: 3481.35\nend_time: 3484.06', metadata={'source': 'metaclass.csv', 'row': 447}),
#  Document(page_content='text: user to create only one instance.\nstart_time: 3484.06\nend_time: 3487.18', metadata={'source': 'metaclass.csv', 'row': 448}),
#  Document(page_content="text: So that's in going to achieve it single to design.\nstart_time: 3487.18\nend_time: 3489.56", metadata={'source': 'metaclass.csv', 'row': 449}),
#  Document(page_content="text: So let's do one thing. implement send real tone meta class to avoid creating more than 1 instance of a class. So, now let us create this class single tone meta class.\nstart_time: 3489.56\nend_time: 3520.31", metadata={'source': 'metaclass.csv', 'row': 450}),
#  Document(page_content="text: Let's see it type okay and by default now we are going to do this same thing in send.\nstart_time: 3520.31\nend_time: 3533.64", metadata={'source': 'metaclass.csv', 'row': 451}),
#  Document(page_content='text: So, it says. is ok. Now, define the call. Thank you. So, one thing we will introduce here that is the condition if CLS not in CLS should create it cls.inst cls equal to 0 I hope this is understandable.\nstart_time: 3533.64\nend_time: 3583.98', metadata={'source': 'metaclass.csv', 'row': 452}),
#  Document(page_content="text: Now let's simply return it. And whenever you want to check what is the length of a view just print the CLS itself. Okay. So now if I create two classes, one, two, three, four, three, four, three, four, three, meter class would be. Thank you. Thanks for watching! And what? And one more thing to notice, if you create two one classes with the different meta classes, will get two objects right. So it is not some magical\nstart_time: 3583.98\nend_time: 3664.86", metadata={'source': 'metaclass.csv', 'row': 453}),
#  Document(page_content='text: but yeah it is useful.\nstart_time: 3664.86\nend_time: 3667.06', metadata={'source': 'metaclass.csv', 'row': 454}),
#  Document(page_content='text: So let us give it some other name. Thank you. So, now as you can see, so we have created two different classes and two different instances right.\nstart_time: 3667.06\nend_time: 3692.8', metadata={'source': 'metaclass.csv', 'row': 455}),
#  Document(page_content='text: So as you can see let us create any number of instances. Thank you. So, if you check the length of it, you just get every time 2 instances right, there is\nstart_time: 3694.72\nend_time: 3719.03', metadata={'source': 'metaclass.csv', 'row': 456}),
#  Document(page_content='text: no more than that.\nstart_time: 3719.03\nend_time: 3720.55', metadata={'source': 'metaclass.csv', 'row': 457}),
#  Document(page_content="text: We can create a number of instances, let's suppose. Thank you. So if I just run them, as you can see there is a lot of number of instances, but if I just print them, so you\nstart_time: 3720.55\nend_time: 3753.72", metadata={'source': 'metaclass.csv', 'row': 458}),
#  Document(page_content='text: get only 2 number of instances, because we have two classes only.\nstart_time: 3753.72\nend_time: 3757.31', metadata={'source': 'metaclass.csv', 'row': 459}),
#  Document(page_content='text: So, that is how we are like limiting the number of instances creation to only one. So that is called the singleton design.\nstart_time: 3757.31\nend_time: 3766.38', metadata={'source': 'metaclass.csv', 'row': 460}),
#  Document(page_content="text: So that's it for this video. I hope you have understood the tutorial and if you have\nstart_time: 3768.14\nend_time: 3772.6", metadata={'source': 'metaclass.csv', 'row': 461}),
#  Document(page_content='text: any kind of comments any kind of queries just let me know in the comments or my link in profile is in the description.\nstart_time: 3772.6\nend_time: 3777.47', metadata={'source': 'metaclass.csv', 'row': 462}),
#  Document(page_content='text: So do follow me and hit the like to this video if you like this and subscribe to the channel and please the bell icon so that you never\nstart_time: 3777.47\nend_time: 3784.62', metadata={'source': 'metaclass.csv', 'row': 463}),
#  Document(page_content='text: miss the latest videos. Thank you.\nstart_time: 3784.62\nend_time: 3786.78', metadata={'source': 'metaclass.csv', 'row': 464})]

# %%
from langchain.llms import OpenAI

llm = OpenAI()
llm("what is 3786.78 sec in min?")
# Out:
# '\n\n378.78 sec is equal to 6.31 minutes.'
